# %%
s1 = {1,2,3,4} #set creation

s1

type(s1)
# Out:
# set

# %%
s2 = set([3,4,5,6])  # another way to create set
s2
# Out:
# {3, 4, 5, 6}

# %%
s3 = {1,2,2,3,4,4}  # duplicate elements will be removed
s3
# Out:
# {1, 2, 3, 4}

# %%
s4 = set("hello")  # set of characters
s4
# Out:
# {'e', 'h', 'l', 'o'}

# %%
s5 = {}
type(s5)  # this is dictionary, not set
# Out:
# dict

# %%
p = {10,20,30,40,50} #unordered results
for i in p:
    print(i)
# Out:
# 50
# 20
# 40
# 10
# 30

# %%
p1 = set('Pushkar') #unordered characters
for i in p1:
    print(i)
# Out:
# k
# s
# h
# a
# r
# P
# u

# %%
s1 = {1,2,3,4} #set creation , CONCEPT OF MUTABILITY
s1.add(999)
s1

s1.add("HI")
s1

s1.add((5,6,7))  # adding tuple
s1
# Out:
# {(5, 6, 7), 1, 2, 3, 4, 999, 'HI'}

# %%
s = {1,2,3}
s.remove(2)  # if element not found, it will raise error
s
# Out:
# {1, 3}

# %%
#in set we cant add list or dictionary as they are mutable , set use hashing concept

s = {1,2,3}
s.add([4,5,6])  # will raise error
s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 4
#       1 #in set we cant add list or dictionary as they are mutable , set use hashing concept
#       3 s = {1,2,3}
# ----> 4 s.add([4,5,6])  # will raise error
#       5 s
#
# TypeError: unhashable type: 'list'

# %%
#pop function removes and returns an arbitrary element from the set.we dont know which element will be removed
s = {1,2,3,4,5} 
s.pop()
s
# Out:
# {2, 3, 4, 5}
