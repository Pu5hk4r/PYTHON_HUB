# %%
#Print file content line by line

with open("sample.txt", "r") as f:
    for line in f:
        print(line.strip())
# Out:
# Python is a powerful programming language
# Python is easy to learn
# File handling in Python is very important
# This file is created for practice
# Error handling is also important
# Python Python Python

# %%
#Read first 10 characters
with open("sample.txt") as f:
    data = f.read(10)
    print(data)
# Out:
# Python is

# %%
#Count numbers of lines

with open("sample.txt", "r") as f:
    print(len(f.readlines()))
# Out:
# 6

# %%
#Lines as list elements

with open("sample.txt", "r") as f:
    lines = [line.strip() for line in f]
print(lines)
# Out:
# ['Python is a powerful programming language', 'Python is easy to learn', 'File handling in Python is very important', 'This file is created for practice', 'Error handling is also important', 'Python Python Python']
